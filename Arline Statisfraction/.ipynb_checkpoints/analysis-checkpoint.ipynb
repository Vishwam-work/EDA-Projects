# %%
# Import the important liberary
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import the Dataset

# %%
db = pd.read_csv('Invistico_Airline.csv')
db.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# ...

# %% [markdown]
# ## Data processing

# %%
db.shape
# Out:
# (129880, 23)

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
# Describe the satistical data
db.describe()
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %% [markdown]
# ### checking null and duplicate values

# %%
db.isnull().sum()
# Out:
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# ...

# %%
db['Arrival Delay in Minutes'].isnull().sum()
# Out:
# 393

# %%
# delete the null value
db1 = db.dropna(axis=0,inplace=False)

# %%
print(db1.shape)
print("Null value record deleted = ",129880-129487)
# Out:
# (129487, 23)
# Null value record deleted =  393

# %%
db1=db1.drop_duplicates(keep='first')

# %%
db1.shape
# Out:
# (129487, 23)

# %%
db1.drop(['satisfaction'],axis=1,inplace=True)

# %%
db1.head()
# Out:
#    Gender   Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0  Female  Loyal Customer   65  Personal Travel       Eco              265
# 1    Male  Loyal Customer   47  Personal Travel  Business             2464
# 2  Female  Loyal Customer   15  Personal Travel       Eco             2138
# 3  Female  Loyal Customer   60  Personal Travel       Eco              623
# 4  Female  Loyal Customer   70  Personal Travel       Eco              354
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Gate location  ...  Online support  Ease of Online booking  \
# ...

# %% [markdown]
# ## correlation

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
db1.corr()
# Out:
#                                         Age  Flight Distance  Seat comfort  \
# Age                                1.000000        -0.249438      0.008475
# Flight Distance                   -0.249438         1.000000     -0.042476
# Seat comfort                       0.008475        -0.042476      1.000000
# Departure/Arrival time convenient  0.038905         0.001381      0.434945
# Food and drink                     0.015496        -0.004806      0.716008
# Gate location                     -0.000805        -0.002322      0.405358
# Inflight wifi service              0.014037         0.012314      0.129152
# Inflight entertainment             0.130254        -0.027344      0.426488
# Online support                     0.121287        -0.031860      0.120153
# Ease of Online booking             0.071728        -0.022326      0.211576
# On-board service                   0.066510        -0.032422      0.121183
# ...

# %%
db1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129487 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129487 non-null  object
#  1   Customer Type                      129487 non-null  object
#  2   Age                                129487 non-null  int64
#  3   Type of Travel                     129487 non-null  object
#  4   Class                              129487 non-null  object
#  5   Flight Distance                    129487 non-null  int64
#  6   Seat comfort                       129487 non-null  int64
#  7   Departure/Arrival time convenient  129487 non-null  int64
#  8   Food and drink                     129487 non-null  int64
#  9   Gate location                      129487 non-null  int64
#  10  Inflight wifi service              129487 non-null  int64
# ...

# %% [markdown]
# ## EDA

# %%
# The components which play major role in staistfraction
fltr =  ['Seat comfort','Ease of Online booking','Departure/Arrival time convenient','Class','Inflight wifi service','On-board service','Cleanliness','Checkin service']
print(fltr)
# Out:
# ['Seat comfort', 'Ease of Online booking', 'Departure/Arrival time convenient', 'Class', 'Inflight wifi service', 'On-board service', 'Cleanliness', 'Checkin service']

# %%
fig = plt.subplots(figsize=(20,25))
for i,j in enumerate(fltr):
    plt.subplot(5,2,i+1)
    plt.subplots_adjust(hspace=0.5)
    sns.countplot(x=j,data=db1)

# %% [markdown]
# ## Conclusion of the EDA

# %%
# So by the Above factors we Analysis
# 1.Alots of customer are rating 4 in every aspect so its a good rating and seem satistfy with the services
# 2.Most of the customer perfer the Bussiness class with good facilites
